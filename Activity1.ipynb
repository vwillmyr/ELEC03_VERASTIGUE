# %% [markdown]
# <h1>Activity 1 - PALMER PENGUINS DATA ANALYTICS PROJECT </h1>
# <hr>
# <h3>Analyst : Willmyr Kurt M. Verastigue<h3>

# %%
#import libraries
import numpy as np
import pandas as pd 
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# <h2>Converting Dataset(s) into DataFrame</h2>

# %% [markdown]
# <h2>REQUIREMENTS</h2>
# <ul>
#     <li>
#         Name of the DataFrame
#     </li>
#     <li>
#         File Path
#     </li>
# </ul>

# %%
penguins = pd.read_csv('Datasets\\penguins.csv')

# %%
penguins
# Out:
#      rowid    species     island  bill_length_mm  bill_depth_mm  \
# 0        1     Adelie  Torgersen            39.1           18.7
# 1        2     Adelie  Torgersen            39.5           17.4
# 2        3     Adelie  Torgersen            40.3           18.0
# 3        4     Adelie  Torgersen             NaN            NaN
# 4        5     Adelie  Torgersen            36.7           19.3
# ..     ...        ...        ...             ...            ...
# 339    340  Chinstrap      Dream            55.8           19.8
# 340    341  Chinstrap      Dream            43.5           18.1
# 341    342  Chinstrap      Dream            49.6           18.2
# 342    343  Chinstrap      Dream            50.8           19.0
# 343    344  Chinstrap      Dream            50.2           18.7
#
#      flipper_length_mm  body_mass_g     sex  year
# 0                181.0       3750.0    male  2007
# 1                186.0       3800.0  female  2007
# ...

# %% [markdown]
# <h2>DESCRIPTIVE ANALYTICS</h2>

# %%
penguins.describe()
# Out:
#             rowid  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# count  344.000000      342.000000     342.000000         342.000000
# mean   172.500000       43.921930      17.151170         200.915205
# std     99.448479        5.459584       1.974793          14.061714
# min      1.000000       32.100000      13.100000         172.000000
# 25%     86.750000       39.225000      15.600000         190.000000
# 50%    172.500000       44.450000      17.300000         197.000000
# 75%    258.250000       48.500000      18.700000         213.000000
# max    344.000000       59.600000      21.500000         231.000000
#
#        body_mass_g         year
# count   342.000000   344.000000
# mean   4201.754386  2008.029070
# std     801.954536     0.818356
# min    2700.000000  2007.000000
# 25%    3550.000000  2007.000000
# 50%    4050.000000  2008.000000
# 75%    4750.000000  2009.000000
# max    6300.000000  2009.000000

# %%
penguins.describe().T
# Out:
#                    count         mean         std     min       25%      50%  \
# rowid              344.0   172.500000   99.448479     1.0    86.750   172.50
# bill_length_mm     342.0    43.921930    5.459584    32.1    39.225    44.45
# bill_depth_mm      342.0    17.151170    1.974793    13.1    15.600    17.30
# flipper_length_mm  342.0   200.915205   14.061714   172.0   190.000   197.00
# body_mass_g        342.0  4201.754386  801.954536  2700.0  3550.000  4050.00
# year               344.0  2008.029070    0.818356  2007.0  2007.000  2008.00
#
#                        75%     max
# rowid               258.25   344.0
# bill_length_mm       48.50    59.6
# bill_depth_mm        18.70    21.5
# flipper_length_mm   213.00   231.0
# body_mass_g        4750.00  6300.0
# year               2009.00  2009.0

# %% [markdown]
# <h2>CHECKING FOR NULL VALUES</h2>

# %%
penguins.isnull()
# Out:
#      rowid  species  island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0    False    False   False           False          False              False
# 1    False    False   False           False          False              False
# 2    False    False   False           False          False              False
# 3    False    False   False            True           True               True
# 4    False    False   False           False          False              False
# ..     ...      ...     ...             ...            ...                ...
# 339  False    False   False           False          False              False
# 340  False    False   False           False          False              False
# 341  False    False   False           False          False              False
# 342  False    False   False           False          False              False
# 343  False    False   False           False          False              False
#
#      body_mass_g    sex   year
# ...

# %%
penguins.isnull().sum()
# Out:
# rowid                 0
# species               0
# island                0
# bill_length_mm        2
# bill_depth_mm         2
# flipper_length_mm     2
# body_mass_g           2
# sex                  11
# year                  0
# dtype: int64

# %% [markdown]
# <h2>FILTERING A COLUMN</h2>

# %%
penguins['species']
# Out:
# 0         Adelie
# 1         Adelie
# 2         Adelie
# 3         Adelie
# 4         Adelie
#          ...
# 339    Chinstrap
# 340    Chinstrap
# 341    Chinstrap
# 342    Chinstrap
# 343    Chinstrap
# Name: species, Length: 344, dtype: object

# %%
penguins['species'].value_counts()
# Out:
# species
# Adelie       152
# Gentoo       124
# Chinstrap     68
# Name: count, dtype: int64

# %%
penguins['species'] == 'Chinstrap'
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 339     True
# 340     True
# 341     True
# 342     True
# 343     True
# Name: species, Length: 344, dtype: bool

# %% [markdown]
# <h2>OPERATORS</h2>

# %%
penguins[penguins['species'] == 'Chinstrap']
# Out:
#      rowid    species island  bill_length_mm  bill_depth_mm  \
# 276    277  Chinstrap  Dream            46.5           17.9
# 277    278  Chinstrap  Dream            50.0           19.5
# 278    279  Chinstrap  Dream            51.3           19.2
# 279    280  Chinstrap  Dream            45.4           18.7
# 280    281  Chinstrap  Dream            52.7           19.8
# ..     ...        ...    ...             ...            ...
# 339    340  Chinstrap  Dream            55.8           19.8
# 340    341  Chinstrap  Dream            43.5           18.1
# 341    342  Chinstrap  Dream            49.6           18.2
# 342    343  Chinstrap  Dream            50.8           19.0
# 343    344  Chinstrap  Dream            50.2           18.7
#
#      flipper_length_mm  body_mass_g     sex  year
# 276              192.0       3500.0  female  2007
# 277              196.0       3900.0    male  2007
# 278              193.0       3650.0    male  2007
# ...

# %%
penguins[penguins['species'] != 'Chinstrap']
# Out:
#      rowid species     island  bill_length_mm  bill_depth_mm  \
# 0        1  Adelie  Torgersen            39.1           18.7
# 1        2  Adelie  Torgersen            39.5           17.4
# 2        3  Adelie  Torgersen            40.3           18.0
# 3        4  Adelie  Torgersen             NaN            NaN
# 4        5  Adelie  Torgersen            36.7           19.3
# ..     ...     ...        ...             ...            ...
# 271    272  Gentoo     Biscoe             NaN            NaN
# 272    273  Gentoo     Biscoe            46.8           14.3
# 273    274  Gentoo     Biscoe            50.4           15.7
# 274    275  Gentoo     Biscoe            45.2           14.8
# 275    276  Gentoo     Biscoe            49.9           16.1
#
#      flipper_length_mm  body_mass_g     sex  year
# 0                181.0       3750.0    male  2007
# 1                186.0       3800.0  female  2007
# 2                195.0       3250.0  female  2007
# ...

# %% [markdown]
# <h2>SEPARATING DATA FRAMES</h2>

# %% [markdown]
# <h3> CHINSTRAP DATA FRAMES </h3>

# %%
chinstrap_df = penguins[penguins['species'] == 'Chinstrap']
chinstrap_df
# Out:
#      rowid    species island  bill_length_mm  bill_depth_mm  \
# 276    277  Chinstrap  Dream            46.5           17.9
# 277    278  Chinstrap  Dream            50.0           19.5
# 278    279  Chinstrap  Dream            51.3           19.2
# 279    280  Chinstrap  Dream            45.4           18.7
# 280    281  Chinstrap  Dream            52.7           19.8
# ..     ...        ...    ...             ...            ...
# 339    340  Chinstrap  Dream            55.8           19.8
# 340    341  Chinstrap  Dream            43.5           18.1
# 341    342  Chinstrap  Dream            49.6           18.2
# 342    343  Chinstrap  Dream            50.8           19.0
# 343    344  Chinstrap  Dream            50.2           18.7
#
#      flipper_length_mm  body_mass_g     sex  year
# 276              192.0       3500.0  female  2007
# 277              196.0       3900.0    male  2007
# 278              193.0       3650.0    male  2007
# ...

# %% [markdown]
# <h3> ADELIE DATA FRAMES </h3>

# %%
adelie_df = penguins[penguins['species'] == 'Adelie']
adelie_df
# Out:
#      rowid species     island  bill_length_mm  bill_depth_mm  \
# 0        1  Adelie  Torgersen            39.1           18.7
# 1        2  Adelie  Torgersen            39.5           17.4
# 2        3  Adelie  Torgersen            40.3           18.0
# 3        4  Adelie  Torgersen             NaN            NaN
# 4        5  Adelie  Torgersen            36.7           19.3
# ..     ...     ...        ...             ...            ...
# 147    148  Adelie      Dream            36.6           18.4
# 148    149  Adelie      Dream            36.0           17.8
# 149    150  Adelie      Dream            37.8           18.1
# 150    151  Adelie      Dream            36.0           17.1
# 151    152  Adelie      Dream            41.5           18.5
#
#      flipper_length_mm  body_mass_g     sex  year
# 0                181.0       3750.0    male  2007
# 1                186.0       3800.0  female  2007
# 2                195.0       3250.0  female  2007
# ...

# %% [markdown]
# <h3> GENTOO DATA FRAMES </h3>

# %%
gentoo_df = penguins[penguins['species'] == 'Gentoo']
gentoo_df
# Out:
#      rowid species  island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 152    153  Gentoo  Biscoe            46.1           13.2              211.0
# 153    154  Gentoo  Biscoe            50.0           16.3              230.0
# 154    155  Gentoo  Biscoe            48.7           14.1              210.0
# 155    156  Gentoo  Biscoe            50.0           15.2              218.0
# 156    157  Gentoo  Biscoe            47.6           14.5              215.0
# ..     ...     ...     ...             ...            ...                ...
# 271    272  Gentoo  Biscoe             NaN            NaN                NaN
# 272    273  Gentoo  Biscoe            46.8           14.3              215.0
# 273    274  Gentoo  Biscoe            50.4           15.7              222.0
# 274    275  Gentoo  Biscoe            45.2           14.8              212.0
# 275    276  Gentoo  Biscoe            49.9           16.1              213.0
#
#      body_mass_g     sex  year
# ...

# %% [markdown]
# <h3> HOW MANY CHINSTRAP IS WEIGHTING OVER 4000G </h3>

# %%
penguins['species'] == 'Chinstrap'
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 339     True
# 340     True
# 341     True
# 342     True
# 343     True
# Name: species, Length: 344, dtype: bool

# %%
penguins['body_mass_g'] >= 4000
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 339     True
# 340    False
# 341    False
# 342     True
# 343    False
# Name: body_mass_g, Length: 344, dtype: bool

# %%
chinstrap_heavy = penguins[(penguins['species'] == 'Chinstrap') & (penguins['body_mass_g'] <= 4000)]
chinstrap_heavy
# Out:
#      rowid    species island  bill_length_mm  bill_depth_mm  \
# 276    277  Chinstrap  Dream            46.5           17.9
# 277    278  Chinstrap  Dream            50.0           19.5
# 278    279  Chinstrap  Dream            51.3           19.2
# 279    280  Chinstrap  Dream            45.4           18.7
# 280    281  Chinstrap  Dream            52.7           19.8
# 281    282  Chinstrap  Dream            45.2           17.8
# 282    283  Chinstrap  Dream            46.1           18.2
# 283    284  Chinstrap  Dream            51.3           18.2
# 285    286  Chinstrap  Dream            51.3           19.9
# 286    287  Chinstrap  Dream            46.6           17.8
# 287    288  Chinstrap  Dream            51.7           20.3
# 288    289  Chinstrap  Dream            47.0           17.3
# 290    291  Chinstrap  Dream            45.9           17.1
# 292    293  Chinstrap  Dream            50.3           20.0
# 293    294  Chinstrap  Dream            58.0           17.8
# ...

# %%
chinstrap_heavy.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 53 entries, 276 to 343
# Data columns (total 9 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   rowid              53 non-null     int64
#  1   species            53 non-null     object
#  2   island             53 non-null     object
#  3   bill_length_mm     53 non-null     float64
#  4   bill_depth_mm      53 non-null     float64
#  5   flipper_length_mm  53 non-null     float64
#  6   body_mass_g        53 non-null     float64
#  7   sex                53 non-null     object
#  8   year               53 non-null     int64
# dtypes: float64(4), int64(2), object(3)
# memory usage: 4.1+ KB

# %% [markdown]
# <h2> FILLING UP MISSING VALUES </h2>

# %%
penguins.isnull().sum()
# Out:
# rowid                 0
# species               0
# island                0
# bill_length_mm        2
# bill_depth_mm         2
# flipper_length_mm     2
# body_mass_g           2
# sex                  11
# year                  0
# dtype: int64

# %%
penguins['bill_length_mm'].isnull().sum()
# Out:
# np.int64(2)

# %%
penguins['bill_length_mm'].mean()
# Out:
# np.float64(43.9219298245614)

# %%
penguins['bill_length_mm'] = penguins['bill_length_mm'].fillna(penguins['bill_length_mm'].mean())

# %%
penguins.isnull().sum()
# Out:
# rowid                 0
# species               0
# island                0
# bill_length_mm        0
# bill_depth_mm         2
# flipper_length_mm     2
# body_mass_g           2
# sex                  11
# year                  0
# dtype: int64

# %%
penguins['bill_depth_mm'].mean()
# Out:
# np.float64(17.151169590643274)

# %%
penguins['bill_depth_mm'] = penguins['bill_depth_mm'].fillna(penguins['bill_depth_mm'].mean())

# %%
penguins.isnull().sum()
# Out:
# rowid                 0
# species               0
# island                0
# bill_length_mm        0
# bill_depth_mm         0
# flipper_length_mm     2
# body_mass_g           2
# sex                  11
# year                  0
# dtype: int64

# %%
penguins['flipper_length_mm'].mean()
# Out:
# np.float64(200.91520467836258)

# %%
penguins['flipper_length_mm'] = penguins['flipper_length_mm'].fillna(penguins['flipper_length_mm'].mean())

# %%
penguins.isnull().sum()
# Out:
# rowid                 0
# species               0
# island                0
# bill_length_mm        0
# bill_depth_mm         0
# flipper_length_mm     0
# body_mass_g           2
# sex                  11
# year                  0
# dtype: int64

# %%
penguins['body_mass_g'].mean()
# Out:
# np.float64(4201.754385964912)

# %%
penguins['body_mass_g'] = penguins['body_mass_g'].fillna(penguins['body_mass_g'].mean())

# %%
penguins.isnull().sum()
# Out:
# rowid                 0
# species               0
# island                0
# bill_length_mm        0
# bill_depth_mm         0
# flipper_length_mm     0
# body_mass_g           0
# sex                  11
# year                  0
# dtype: int64

# %%
penguins['sex'].mode()
# Out:
# 0    male
# Name: sex, dtype: object

# %%
penguins['sex'] = penguins['sex'].fillna(penguins['sex'].mode()[0])

# %%
penguins.isnull().sum()
# Out:
# rowid                0
# species              0
# island               0
# bill_length_mm       0
# bill_depth_mm        0
# flipper_length_mm    0
# body_mass_g          0
# sex                  0
# year                 0
# dtype: int64

# %%
#penguins_sex = penguins[penguins['sex'] == 'male']
#penguins_sex

# %% [markdown]
# <h2>CHANGING DATA TYPES</h2>

# %%
penguins
# Out:
#      rowid    species     island  bill_length_mm  bill_depth_mm  \
# 0        1     Adelie  Torgersen        39.10000       18.70000
# 1        2     Adelie  Torgersen        39.50000       17.40000
# 2        3     Adelie  Torgersen        40.30000       18.00000
# 3        4     Adelie  Torgersen        43.92193       17.15117
# 4        5     Adelie  Torgersen        36.70000       19.30000
# ..     ...        ...        ...             ...            ...
# 339    340  Chinstrap      Dream        55.80000       19.80000
# 340    341  Chinstrap      Dream        43.50000       18.10000
# 341    342  Chinstrap      Dream        49.60000       18.20000
# 342    343  Chinstrap      Dream        50.80000       19.00000
# 343    344  Chinstrap      Dream        50.20000       18.70000
#
#      flipper_length_mm  body_mass_g     sex  year
# 0           181.000000  3750.000000    male  2007
# 1           186.000000  3800.000000  female  2007
# ...

# %%
penguins['species'] = penguins['species'].astype('category')
penguins['island'] = penguins['island'].astype('category')
penguins['sex'] = penguins['sex'].astype('category')
penguins['year'] = penguins['year'].astype('category')

# %%
penguins.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 344 entries, 0 to 343
# Data columns (total 9 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   rowid              344 non-null    int64
#  1   species            344 non-null    category
#  2   island             344 non-null    category
#  3   bill_length_mm     344 non-null    float64
#  4   bill_depth_mm      344 non-null    float64
#  5   flipper_length_mm  344 non-null    float64
#  6   body_mass_g        344 non-null    float64
#  7   sex                344 non-null    category
#  8   year               344 non-null    category
# dtypes: category(4), float64(4), int64(1)
# memory usage: 15.4 KB

# %%
penguins.isnull().sum()
# Out:
# rowid                0
# species              0
# island               0
# bill_length_mm       0
# bill_depth_mm        0
# flipper_length_mm    0
# body_mass_g          0
# sex                  0
# year                 0
# dtype: int64

# %%
penguins.describe()
# Out:
#             rowid  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# count  344.000000      344.000000     344.000000         344.000000
# mean   172.500000       43.921930      17.151170         200.915205
# std     99.448479        5.443643       1.969027          14.020657
# min      1.000000       32.100000      13.100000         172.000000
# 25%     86.750000       39.275000      15.600000         190.000000
# 50%    172.500000       44.250000      17.300000         197.000000
# 75%    258.250000       48.500000      18.700000         213.000000
# max    344.000000       59.600000      21.500000         231.000000
#
#        body_mass_g
# count   344.000000
# mean   4201.754386
# std     799.613058
# min    2700.000000
# 25%    3550.000000
# 50%    4050.000000
# 75%    4750.000000
# max    6300.000000

# %% [markdown]
# <h2>EXAMPLE QUESTION AND INSIGHTS</h2>

# %% [markdown]
# <h3>Which species has the heaviest body mass?</h3>

# %%
penguins['body_mass_g'].mean()
# Out:
# np.float64(4201.754385964912)

# %%
gentoo_df = penguins[penguins['species'] == 'Gentoo']

# %%
gentoo_df['body_mass_g'].mean()
# Out:
# np.float64(5068.965761177136)

# %%
chinstrap_df = penguins[penguins['species'] == 'Chinstrap']
chinstrap_df
# Out:
#      rowid    species island  bill_length_mm  bill_depth_mm  \
# 276    277  Chinstrap  Dream            46.5           17.9
# 277    278  Chinstrap  Dream            50.0           19.5
# 278    279  Chinstrap  Dream            51.3           19.2
# 279    280  Chinstrap  Dream            45.4           18.7
# 280    281  Chinstrap  Dream            52.7           19.8
# ..     ...        ...    ...             ...            ...
# 339    340  Chinstrap  Dream            55.8           19.8
# 340    341  Chinstrap  Dream            43.5           18.1
# 341    342  Chinstrap  Dream            49.6           18.2
# 342    343  Chinstrap  Dream            50.8           19.0
# 343    344  Chinstrap  Dream            50.2           18.7
#
#      flipper_length_mm  body_mass_g     sex  year
# 276              192.0       3500.0  female  2007
# 277              196.0       3900.0    male  2007
# 278              193.0       3650.0    male  2007
# ...

# %%
chinstrap_df['body_mass_g'].mean()
# Out:
# np.float64(3733.0882352941176)

# %%
adelie_df = penguins[penguins['species'] == 'Adelie']

# %%
adelie_df['body_mass_g'].mean()
# Out:
# np.float64(3703.95891043398)

# %% [markdown]
# <h4> INSIGHTS: Gentoo has the heaviest average body mass</h4>

# %% [markdown]
# <h2> HOW TO CREATE YOUR COLUMNS </h2>

# %%
penguins.columns
# Out:
# Index(['rowid', 'species', 'island', 'bill_length_mm', 'bill_depth_mm',
#        'flipper_length_mm', 'body_mass_g', 'sex', 'year'],
#       dtype='object')

# %%
penguins.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 344 entries, 0 to 343
# Data columns (total 9 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   rowid              344 non-null    int64
#  1   species            344 non-null    category
#  2   island             344 non-null    category
#  3   bill_length_mm     344 non-null    float64
#  4   bill_depth_mm      344 non-null    float64
#  5   flipper_length_mm  344 non-null    float64
#  6   body_mass_g        344 non-null    float64
#  7   sex                344 non-null    category
#  8   year               344 non-null    category
# dtypes: category(4), float64(4), int64(1)
# memory usage: 15.4 KB

# %%
penguins['mass_kg'] = np.round(penguins['body_mass_g'] /1000,1)

# %%
penguins.isnull().sum()
# Out:
# rowid                0
# species              0
# island               0
# bill_length_mm       0
# bill_depth_mm        0
# flipper_length_mm    0
# body_mass_g          0
# sex                  0
# year                 0
# mass_kg              0
# dtype: int64

# %% [markdown]
# <h1>SELF-EXPLANATORY DATA ANALYTICS</h1>

# %% [markdown]
# <h2>QUESTION #1</h2>

# %% [markdown]
# <h2>Which among the male and female species has the highest number of records on year 2007?</h2>
# <hr>

# %% [markdown]
# <h2>Male</h2>

# %%
penguins[(penguins['year'] == 2007) & (penguins['sex'] == 'male')]
# Out:
#      rowid    species     island  bill_length_mm  bill_depth_mm  \
# 0        1     Adelie  Torgersen        39.10000       18.70000
# 3        4     Adelie  Torgersen        43.92193       17.15117
# 5        6     Adelie  Torgersen        39.30000       20.60000
# 7        8     Adelie  Torgersen        39.20000       19.60000
# 8        9     Adelie  Torgersen        34.10000       18.10000
# 9       10     Adelie  Torgersen        42.00000       20.20000
# 10      11     Adelie  Torgersen        37.80000       17.10000
# 11      12     Adelie  Torgersen        37.80000       17.30000
# 13      14     Adelie  Torgersen        38.60000       21.20000
# 14      15     Adelie  Torgersen        34.60000       21.10000
# 17      18     Adelie  Torgersen        42.50000       20.70000
# 19      20     Adelie  Torgersen        46.00000       21.50000
# 21      22     Adelie     Biscoe        37.70000       18.70000
# 23      24     Adelie     Biscoe        38.20000       18.10000
# ...

# %% [markdown]
# <h2>Female</h2>

# %%
penguins[(penguins['year'] == 2007) & (penguins['sex'] == 'female')]
# Out:
#      rowid    species     island  bill_length_mm  bill_depth_mm  \
# 1        2     Adelie  Torgersen            39.5           17.4
# 2        3     Adelie  Torgersen            40.3           18.0
# 4        5     Adelie  Torgersen            36.7           19.3
# 6        7     Adelie  Torgersen            38.9           17.8
# 12      13     Adelie  Torgersen            41.1           17.6
# 15      16     Adelie  Torgersen            36.6           17.8
# 16      17     Adelie  Torgersen            38.7           19.0
# 18      19     Adelie  Torgersen            34.4           18.4
# 20      21     Adelie     Biscoe            37.8           18.3
# 22      23     Adelie     Biscoe            35.9           19.2
# 25      26     Adelie     Biscoe            35.3           18.9
# 27      28     Adelie     Biscoe            40.5           17.9
# 28      29     Adelie     Biscoe            37.9           18.6
# 30      31     Adelie      Dream            39.5           16.7
# ...

# %% [markdown]
# <h2>Results of Male</h2>

# %%
male_2007_count = ((penguins['year'] == 2007) & (penguins['sex'] == 'male')).sum()
male_2007_count
# Out:
# np.int64(59)

# %% [markdown]
# <h2>Results of Female</h2>

# %%
female_2007_count = ((penguins['year'] == 2007) & (penguins['sex'] == 'female')).sum()
female_2007_count
# Out:
# np.int64(51)

# %% [markdown]
# <h3>INSIGHTS: </h3>

# %% [markdown]
# We show in the given results that the highest record in the year 2007 was the male count, which was 59, and then the female count was 51.

# %% [markdown]
# <hr>
# <h2>QUESTION #2</h2>

# %% [markdown]
# <h2>How many penguins in the palmer penguins database weigh less than 3500 grams?</h2>

# %%
penguins[penguins['body_mass_g'] <= 3500].value_counts('body_mass_g')
# Out:
# body_mass_g
# 3400.0    8
# 3450.0    8
# 3500.0    7
# 3300.0    6
# 3200.0    5
# 3250.0    5
# 3325.0    5
# 3350.0    5
# 3150.0    4
# 3050.0    4
# 2900.0    4
# 3475.0    3
# 2850.0    2
# 3000.0    2
# 3425.0    2
# 3175.0    2
# 2700.0    1
# 2925.0    1
# 2975.0    1
# 3275.0    1
# 3075.0    1
# 3100.0    1
# Name: count, dtype: int64

# %%
peguins_heavy = penguins[penguins['body_mass_g'] <= 3500].value_counts('body_mass_g')

# %%
peguins_heavy.sum()
# Out:
# np.int64(78)

# %% [markdown]
# <h3>INSIGHTS: </h3>

# %% [markdown]
# The analysis shows that there are 78 penguins in the Palmer Penguins database with a body mass of 3500 grams or less. The code provides a detailed breakdown of the number of penguins at specific weights and confirms the total count.

# %% [markdown]
# <hr>
# <h2>QUESTION #3</h2>

# %% [markdown]
# <h2>Which penguins in the database have a bill length that is more than 50mm, a bill depth that is more than 40mm?</h2>

# %%
penguins[(penguins['bill_length_mm'] > 50) | (penguins['bill_depth_mm'] > 40)]
# Out:
#      rowid    species  island  bill_length_mm  bill_depth_mm  \
# 172    173     Gentoo  Biscoe            50.2           14.3
# 185    186     Gentoo  Biscoe            59.6           17.0
# 196    197     Gentoo  Biscoe            50.5           15.9
# 199    200     Gentoo  Biscoe            50.5           15.9
# 205    206     Gentoo  Biscoe            50.1           15.0
# 211    212     Gentoo  Biscoe            50.4           15.3
# 215    216     Gentoo  Biscoe            54.3           15.7
# 221    222     Gentoo  Biscoe            50.7           15.0
# 229    230     Gentoo  Biscoe            51.1           16.3
# 233    234     Gentoo  Biscoe            52.5           15.6
# 237    238     Gentoo  Biscoe            50.8           17.3
# 239    240     Gentoo  Biscoe            51.3           14.2
# 241    242     Gentoo  Biscoe            52.1           17.0
# 243    244     Gentoo  Biscoe            52.2           17.1
# ...

# %%
big_bill_penguins = penguins[(penguins['bill_length_mm'] > 50) | (penguins['bill_depth_mm'] > 40)]
big_bill_penguins['species'].value_counts()
# Out:
# species
# Chinstrap    30
# Gentoo       22
# Adelie        0
# Name: count, dtype: int64

# %% [markdown]
# <h3>INSIGHTS: </h3>

# %% [markdown]
# Based on the result provided, the penguins that meet these criteria are from the Chinstrap and Gentoo species. There are 30 Chinstrap penguins with a bill length greater than 50mm or a bill depth greater than 40mm. There are 22 Gentoo penguins that meet the same criteria. There are no Adelie penguins that meet these conditions.

# %% [markdown]
# <hr>
# <h2>QUESTION #4</h2>

# %% [markdown]
# <h2>What is the average length of the flipper of a penguin and define each species?</h2>

# %%
penguins['flipper_length_mm'].mean()
# Out:
# np.float64(200.91520467836258)

# %%
avg_species =penguins.groupby(['species'])['flipper_length_mm'].mean()

# %%
avg_species
# Out:
# species
# Adelie       190.025758
# Chinstrap    195.823529
# Gentoo       217.055768
# Name: flipper_length_mm, dtype: float64

# %% [markdown]
# <h3> INSIGHTS: </h3>

# %% [markdown]
# Based on the result provided, While the overall average is around 200.9 mm, there are notable differences when looking at individual species. Gentoo penguins have the longest flippers, with an average length of 217 mm. In contrast, Adelie penguins have the shortest flippers, averaging 190 mm, while Chinstrap penguins have an average of 196 mm.

# %% [markdown]
# <hr>
# <h2>QUESTION #5</h2>

# %% [markdown]
# <h2>What is the typical mass of a Gentoo penguin in kilogram?</h2>

# %%
penguins[penguins['species'] == 'Gentoo']['mass_kg'].max()
# Out:
# np.float64(6.3)

# %%
gentoo_df = penguins[penguins['species'] == 'Gentoo']
gentoo_df
# Out:
#      rowid species  island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 152    153  Gentoo  Biscoe        46.10000       13.20000         211.000000
# 153    154  Gentoo  Biscoe        50.00000       16.30000         230.000000
# 154    155  Gentoo  Biscoe        48.70000       14.10000         210.000000
# 155    156  Gentoo  Biscoe        50.00000       15.20000         218.000000
# 156    157  Gentoo  Biscoe        47.60000       14.50000         215.000000
# ..     ...     ...     ...             ...            ...                ...
# 271    272  Gentoo  Biscoe        43.92193       17.15117         200.915205
# 272    273  Gentoo  Biscoe        46.80000       14.30000         215.000000
# 273    274  Gentoo  Biscoe        50.40000       15.70000         222.000000
# 274    275  Gentoo  Biscoe        45.20000       14.80000         212.000000
# 275    276  Gentoo  Biscoe        49.90000       16.10000         213.000000
#
#      body_mass_g     sex  year  mass_kg
# ...

# %% [markdown]
# <h3> INSIGHTS: </h3>

# %% [markdown]
# Based on the result provided, the typical mass of an Gentoo penguin was 6.3kg.

# %% [markdown]
# <hr>
# <h2>QUESTION #6</h2>

# %% [markdown]
# <h2>Which of the Three Islands Hosts the Largest Penguin Population?</h2>

# %%
penguins['island'].value_counts()
# Out:
# island
# Biscoe       168
# Dream        124
# Torgersen     52
# Name: count, dtype: int64

# %% [markdown]
# <h3>INSIGHTS: </h3>

# %% [markdown]
# Based on the result, Biscoe Island is the most largest penguin population, with 168 penguins. This is much higher than Dream Island’s 124 penguins and Torgersen Island’s 52 penguins. Each island hosts different species, but Biscoe stands out with the biggest overall number of penguins.

# %% [markdown]
# <hr>
# <h2>QUESTION #7</h2>

# %% [markdown]
# <h2>What is the average mass in kilograms per species?</h2>

# %% [markdown]
# <h3>Average of Adelie</h3>

# %%
penguins[penguins['species'] == 'Adelie']['mass_kg'].mean().round()
# Out:
# np.float64(4.0)

# %% [markdown]
# <h3>Average of Chinstrap</h3>

# %%
penguins[penguins['species'] == 'Chinstrap']['mass_kg'].mean().round()
# Out:
# np.float64(4.0)

# %% [markdown]
# <h3>Average of Gentoo</h3>

# %%
penguins[penguins['species'] == 'Gentoo']['mass_kg'].mean().round()
# Out:
# np.float64(5.0)

# %% [markdown]
# <h3>INSIGHTS:</h3>

# %% [markdown]
# Gentoo penguins are the heaviest, weighing about 5 kg on average. Adelie and Chinstrap penguins both weigh around 4 kg. Some Adelie and Chinstrap penguins are smaller, weighing 3.5 kg or less.

# %% [markdown]
# <hr>
# <h2>QUESTION #8</h2>

# %% [markdown]
# <h2>On year 2007-2009 which among the three species are in the middle of the shortest and the lowest?</h2>
# <hr>

# %%
species_year = penguins.groupby(['species','year']).size()
species_year
# Out:
# species    year
# Adelie     2007    50
#            2008    50
#            2009    52
# Chinstrap  2007    26
#            2008    18
#            2009    24
# Gentoo     2007    34
#            2008    46
#            2009    44
# dtype: int64

# %%
penguins['species'].value_counts()
# Out:
# species
# Adelie       152
# Gentoo       124
# Chinstrap     68
# Name: count, dtype: int64

# %% [markdown]
# <h3>INSIGHTS:</h3>

# %% [markdown]
# Based on the results, The Gentoo penguin has a total count of 124, placing it in the middle between the Chinstrap and Adelie species, with counts consistently in the middle range each year. The Chinstrap has the lowest total count at 68 and consistently records the lowest count each year. In contrast, the Adelie penguin has the highest total count at 152 and consistently has the highest count each year.

# %% [markdown]
# <hr>
# <h2>QUESTION #9</h2>

# %% [markdown]
# <h3>Is there a difference in mass between male and female penguins at each island?</h3>

# %%
mass_kg = penguins.groupby(['species','sex','island'])['mass_kg'].mean()
mass_kg
# Out:
# species    sex     island
# Adelie     female  Biscoe       3.372727
#                    Dream        3.344444
#                    Torgersen    3.387500
#            male    Biscoe       4.059091
#                    Dream        4.013793
#                    Torgersen    3.989286
# Chinstrap  female  Biscoe            NaN
#                    Dream        3.523529
#                    Torgersen         NaN
#            male    Biscoe            NaN
#                    Dream        3.938235
#                    Torgersen         NaN
# Gentoo     female  Biscoe       4.681034
#                    Dream             NaN
#                    Torgersen         NaN
#            male    Biscoe       5.410606
#                    Dream             NaN
#                    Torgersen         NaN
# Name: mass_kg, dtype: float64

# %% [markdown]
# <h3>INSIGHTS:</h3>

# %% [markdown]
# Based on the results, Males of the Adelie penguin species are heavier than females across all islands, while there is insufficient data for Chinstrap penguins to compare male and female mass, and for Gentoo penguins, males appear heavier on Biscoe Island, with no data available for other islands.

# %% [markdown]
# <hr>
# <h2>QUESTION #10</h2>

# %% [markdown]
# <h3>Which of the male and female penguins has the shortest length of a bill?</h3>

# %%
sex_islands = penguins.groupby(['sex','island','bill_length_mm']).size()
sex_islands
# Out:
# sex     island     bill_length_mm
# female  Biscoe     32.1              0
#                    33.1              0
#                    33.5              0
#                    34.0              0
#                    34.1              0
#                                     ..
# male    Torgersen  55.1              0
#                    55.8              0
#                    55.9              0
#                    58.0              0
#                    59.6              0
# Length: 990, dtype: int64

# %% [markdown]
# <h3>INSIGHTS:</h3>

# %% [markdown]
# Based on the result provided, The female penguin has the shortest bill length recorded at 32.1 mm then the Male penguins have significantly longer bill lengths than the female penguins, with their shortest recorded bill length starting at 55.1 mm.

# %% [markdown]
# <hr>
# <h2>QUESTION #11</h2>

# %% [markdown]
# <h3>Which species has the widest bill of an penguin?</h3>

# %%
avg_species = penguins.groupby(['species'])['bill_depth_mm'].mean()
avg_species
# Out:
# species
# Adelie       18.338495
# Chinstrap    18.420588
# Gentoo       14.999606
# Name: bill_depth_mm, dtype: float64

# %% [markdown]
# <h3>INSIGHTS:</h3>

# %% [markdown]
# The Chinstrap penguin has the widest bill depth at 18.4 mm, then Adelie follows closely with an average of 18.3 mm.then the Gentoo penguin has a shortest bill depth at 14.9 mm.

# %% [markdown]
# <hr>
# <h2>QUESTION #12</h2>

# %% [markdown]
# <h2>In which particular year are there the fewest records found on the island</h2>

# %%
year_island = penguins.groupby(['year','island']).count()
year_island
# Out:
#                 rowid  species  bill_length_mm  bill_depth_mm  \
# year island
# 2007 Biscoe        44       44              44             44
#      Dream         46       46              46             46
#      Torgersen     20       20              20             20
# 2008 Biscoe        64       64              64             64
#      Dream         34       34              34             34
#      Torgersen     16       16              16             16
# 2009 Biscoe        60       60              60             60
#      Dream         44       44              44             44
#      Torgersen     16       16              16             16
#
#                 flipper_length_mm  body_mass_g  sex  mass_kg
# year island
# 2007 Biscoe                    44           44   44       44
#      Dream                     46           46   46       46
#      Torgersen                 20           20   20       20
# 2008 Biscoe                    64           64   64       64
# ...

# %%
penguins['year'].value_counts()
# Out:
# year
# 2009    120
# 2008    114
# 2007    110
# Name: count, dtype: int64

# %% [markdown]
# <h3>INSIGHTS:</h3>

# %% [markdown]
# In 2007, Torgersen Island recorded the fewest total records at 20. However, both 2008 and 2009 also saw lower counts on Torgersen, each with only 16 records.

# %% [markdown]
# <hr>
# <h2>QUESTION #13</h2>

# %% [markdown]
# <h3>What does the p-value indicate regarding the difference in flipper length between male and female penguins?</h3>

# %%
stats, p_value = f_oneway(penguins[penguins['sex'] == 'male']['flipper_length_mm'],penguins[penguins['sex'] == 'female']['flipper_length_mm'])

# %%
p_value
# Out:
# np.float64(4.88065474065626e-06)

# %% [markdown]
# <h3>INSIGHTS:</h3>

# %% [markdown]
# Given the extremely low p-value, we can confidently say that male and female penguins have significantly different flipper lengths.

# %% [markdown]
# <hr>

# %% [markdown]
# <h2>DATA AGGREGATION</h2>

# %% [markdown]
# <h3>1.Ilan species ng penguin ang nakatira per island?</h3>

# %%
species_island = penguins.groupby(['species','island']).count()

# %%
species_island
# Out:
#                      rowid  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# species   island
# Adelie    Biscoe        44              44             44                 44
#           Dream         56              56             56                 56
#           Torgersen     52              52             52                 52
# Chinstrap Biscoe         0               0              0                  0
#           Dream         68              68             68                 68
#           Torgersen      0               0              0                  0
# Gentoo    Biscoe       124             124            124                124
#           Dream          0               0              0                  0
#           Torgersen      0               0              0                  0
#
#                      body_mass_g  sex  year  mass_kg
# species   island
# Adelie    Biscoe              44   44    44       44
#           Dream               56   56    56       56
# ...

# %%
species_islands = penguins.groupby(['species','island']).size()

# %%
species_islands
# Out:
# species    island
# Adelie     Biscoe        44
#            Dream         56
#            Torgersen     52
# Chinstrap  Biscoe         0
#            Dream         68
#            Torgersen      0
# Gentoo     Biscoe       124
#            Dream          0
#            Torgersen      0
# dtype: int64

# %%
species_islands1 = penguins.groupby(['species','island','sex']).size()

# %%
species_islands1
# Out:
# species    island     sex
# Adelie     Biscoe     female    22
#                       male      22
#            Dream      female    27
#                       male      29
#            Torgersen  female    24
#                       male      28
# Chinstrap  Biscoe     female     0
#                       male       0
#            Dream      female    34
#                       male      34
#            Torgersen  female     0
#                       male       0
# Gentoo     Biscoe     female    58
#                       male      66
#            Dream      female     0
#                       male       0
#            Torgersen  female     0
#                       male       0
# dtype: int64

# %% [markdown]
# <h3>2. average weight of penguin per island and sex?</h3>

# %%
avg_island_s =penguins.groupby(['species','island','sex'])['body_mass_g'].mean()

# %%
avg_island_s
# Out:
# species    island     sex
# Adelie     Biscoe     female    3369.318182
#                       male      4050.000000
#            Dream      female    3344.444444
#                       male      4008.620690
#            Torgersen  female    3395.833333
#                       male      3990.241228
# Chinstrap  Biscoe     female            NaN
#                       male              NaN
#            Dream      female    3527.205882
#                       male      3938.970588
#            Torgersen  female            NaN
#                       male              NaN
# Gentoo     Biscoe     female    4679.741379
#                       male      5411.011430
#            Dream      female            NaN
#                       male              NaN
#            Torgersen  female            NaN
#                       male              NaN
# Name: body_mass_g, dtype: float64

# %% [markdown]
# <h1>CORRELATION ANALYSIS</h1>
# <hr>
# <h3>Testing Correlation using Pearson R</h3>
# <hr>
# <p><b>Pearson R</b> can test correlation between two Variables, given that both Variables are <strong>NUMERICAL DATA</strong></p>

# %%
penguins.dtypes
# Out:
# rowid                   int64
# species              category
# island               category
# bill_length_mm        float64
# bill_depth_mm         float64
# flipper_length_mm     float64
# body_mass_g           float64
# sex                  category
# year                 category
# mass_kg               float64
# dtype: object

# %%
flipper_mass = penguins['body_mass_g'].corr(penguins['flipper_length_mm'])

# %%
flipper_mass
# Out:
# np.float64(0.8712017673060114)

# %% [markdown]
# <h2>Installing Scipy</h2>

# %%
# !pip install scipy

# %%
# !python -m pip install --upgrade pip

# %%
penguins[penguins['sex'] == 'male']
# Out:
#      rowid    species     island  bill_length_mm  bill_depth_mm  \
# 0        1     Adelie  Torgersen        39.10000       18.70000
# 3        4     Adelie  Torgersen        43.92193       17.15117
# 5        6     Adelie  Torgersen        39.30000       20.60000
# 7        8     Adelie  Torgersen        39.20000       19.60000
# 8        9     Adelie  Torgersen        34.10000       18.10000
# ..     ...        ...        ...             ...            ...
# 334    335  Chinstrap      Dream        50.20000       18.80000
# 336    337  Chinstrap      Dream        51.90000       19.50000
# 339    340  Chinstrap      Dream        55.80000       19.80000
# 341    342  Chinstrap      Dream        49.60000       18.20000
# 342    343  Chinstrap      Dream        50.80000       19.00000
#
#      flipper_length_mm  body_mass_g   sex  year  mass_kg
# 0           181.000000  3750.000000  male  2007      3.8
# 3           200.915205  4201.754386  male  2007      4.2
# ...

# %%
from scipy.stats import f_oneway

# %%
penguins[penguins['sex'] == 'male']['body_mass_g']
# Out:
# 0      3750.000000
# 3      4201.754386
# 5      3650.000000
# 7      4675.000000
# 8      3475.000000
#           ...
# 334    3800.000000
# 336    3950.000000
# 339    4000.000000
# 341    3775.000000
# 342    4100.000000
# Name: body_mass_g, Length: 179, dtype: float64

# %%
stats, p_value = f_oneway(penguins[penguins['sex'] == 'male']['body_mass_g'],penguins[penguins['sex'] == 'female']['body_mass_g'])

# %%
p_value
# Out:
# np.float64(3.0226600487050246e-15)

# %%
flipper_mass = penguins['body_mass_g'].corr(penguins['flipper_length_mm'])

# %%
flipper_mass
# Out:
# np.float64(0.8712017673060114)

# %% [markdown]
# <hr>

# %% [markdown]
# <h1>CATEGORICAL DATA</h1>

# %% [markdown]
# <h2>BODY MASS VS SEX</h2>

# %%
#import scipy.stats
from scipy.stats import f_oneway

# %%
#FILTER DATA
penguins['sex'] == 'male'
# Out:
# 0       True
# 1      False
# 2      False
# 3       True
# 4      False
#        ...
# 339     True
# 340    False
# 341     True
# 342     True
# 343    False
# Name: sex, Length: 344, dtype: bool

# %%
penguins[penguins['sex'] == 'male']['body_mass_g']
# Out:
# 0      3750.000000
# 3      4201.754386
# 5      3650.000000
# 7      4675.000000
# 8      3475.000000
#           ...
# 334    3800.000000
# 336    3950.000000
# 339    4000.000000
# 341    3775.000000
# 342    4100.000000
# Name: body_mass_g, Length: 179, dtype: float64

# %%
penguins[penguins['sex'] == 'female']['body_mass_g']
# Out:
# 1      3800.0
# 2      3250.0
# 4      3450.0
# 6      3625.0
# 12     3200.0
#         ...
# 335    3525.0
# 337    3650.0
# 338    3650.0
# 340    3400.0
# 343    3775.0
# Name: body_mass_g, Length: 165, dtype: float64

# %%
no_use, p_value = f_oneway(penguins[penguins['sex'] == 'male']['body_mass_g'], penguins[penguins['sex'] == 'female']['body_mass_g'])

# %%
p_value
# Out:
# np.float64(3.0226600487050246e-15)

# %% [markdown]
# <hr>
